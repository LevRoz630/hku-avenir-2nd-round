# %%
from src.hist_data import HistoricalDataCollector
instance = HistoricalDataCollector(days = 1)
# Out:
# 2025-09-21 17:57:21,387 - INFO - Historical Data Collector initialized for 1 days

# %% [markdown]
# Give the coins in ETH-USDT Format, the format is converted to native ccxt internally

# %%
instance.collect_perpetual_mark_ohlcv("ETH-USDT", "5m")
# Out:
# 2025-09-21 17:57:22,522 - INFO - Collecting perpetual mark price OHLCV for ETH-USDT...
# 2025-09-21 17:57:30,028 - INFO -   Perpetual mark OHLCV batch 1/1: 288 records
# 2025-09-21 17:57:30,148 - INFO -   Saved perpetual mark OHLCV for ETH-USDT: 288 records to perpetual_ETH-USDT_mark_5m_1d.csv

# %% [markdown]
# Where timeframe is available it can be "5m","15m","30m","1h","2h","4h","6h","12h", or "1d"

# %% [markdown]
# Saves it into csv files in /historical_data

# %%
instance.collect_historical_funding_rates("ETH-USDT", type = "future")
# Out:
# 2025-09-21 17:57:32,263 - INFO - Collecting historical funding rates for ETH-USDT...
# 2025-09-21 17:57:32,265 - INFO - Collecting funding rates for ETH-USDT...
# 2025-09-21 17:57:32,604 - INFO -   Saved ETH-USDT: 3 funding rate records to future_ETH-USDT_funding_rates_1d.csv

# %%
instance.collect_historical_funding_rates("ETH-USDT", type = "future")
# Out:
# 2025-09-21 17:57:41,971 - INFO - Collecting historical funding rates for ETH-USDT...
# 2025-09-21 17:57:41,974 - INFO - Collecting funding rates for ETH-USDT...
# 2025-09-21 17:57:42,382 - INFO -   Saved ETH-USDT: 3 funding rate records to future_ETH-USDT_funding_rates_1d.csv

# %%
instance.collect_historical_funding_rates("ETH-USDT", type = "future")
# Out:
# 2025-09-21 17:57:48,541 - INFO - Collecting historical funding rates for ETH-USDT...
# 2025-09-21 17:57:48,544 - INFO - Collecting funding rates for ETH-USDT...
# 2025-09-21 17:57:48,821 - INFO -   Saved ETH-USDT: 3 funding rate records to future_ETH-USDT_funding_rates_1d.csv

# %%
# too much data otherwise
instance = HistoricalDataCollector(days = 0.01)
instance.collect_historical_trades("ETH-USDT", type = "future")
# Out:
# 2025-09-21 17:58:10,292 - INFO - Historical Data Collector initialized for 0.01 days
# 2025-09-21 17:58:10,298 - INFO - Collecting historical trades for ETH-USDT (last 0.01 days)...
# 2025-09-21 17:58:10,301 - INFO - Collecting trades for ETH-USDT...
# 2025-09-21 17:58:19,062 - INFO -   Batch 2025-09-21 17:43:46.306113: 1000 trades
# 2025-09-21 17:58:21,104 - INFO -   Batch 2025-09-21 17:44:28.406000: 1000 trades
# 2025-09-21 17:58:23,252 - INFO -   Batch 2025-09-21 17:45:26.401000: 1000 trades
# 2025-09-21 17:58:25,184 - INFO -   Batch 2025-09-21 17:46:26.886000: 1000 trades
# 2025-09-21 17:58:27,188 - INFO -   Batch 2025-09-21 17:47:14.058000: 1000 trades
# 2025-09-21 17:58:29,466 - INFO -   Batch 2025-09-21 17:49:06.779000: 1000 trades
# 2025-09-21 17:58:31,419 - INFO -   Batch 2025-09-21 17:49:45.623000: 1000 trades
# 2025-09-21 17:58:33,326 - INFO -   Batch 2025-09-21 17:50:46.618000: 1000 trades
# 2025-09-21 17:58:35,403 - INFO -   Batch 2025-09-21 17:52:14.804000: 1000 trades
# ...

# %%
instance = HistoricalDataCollector(days = 1, type = "spot", symbols = ["ETH-USDT"])
# Out:
# 2025-09-14 17:04:24,535 - INFO - Historical Data Collector initialized for 1 days

# %%
instance.collect_historical_ohlcv(timeframe = "5m")
# Out:
# 2025-09-14 17:03:50,178 - INFO - Collecting historical OHLCV data (5m) for 1 symbols...
# 2025-09-14 17:03:50,180 - INFO - Total periods needed: 96
# 2025-09-14 17:03:50,182 - INFO - Number of batches: 1
# 2025-09-14 17:03:50,183 - INFO - Collecting ETH-USDT...
# 2025-09-14 17:03:50,455 - INFO -   Batch 1/1: 288 records
# 2025-09-14 17:03:50,576 - INFO -   Saved ETH-USDT: 288 records to spot_ETH-USDT_5m_1d.csv

# %%
instance = HistoricalDataCollector(days = 0.01, type = "spot", symbols = ["ETH-USDT"])
instance.collect_historical_trades()
# Out:
# 2025-09-14 17:04:07,951 - INFO - Historical Data Collector initialized for 0.01 days
# 2025-09-14 17:04:08,016 - INFO - Collecting historical trades for 1 symbols (last 0.01 days)...
# 2025-09-14 17:04:08,020 - INFO - Collecting trades for ETH-USDT...
# 2025-09-14 17:04:16,561 - INFO -   Batch 2025-09-14 16:49:44.023982: 1000 trades
# 2025-09-14 17:04:17,371 - INFO -   Batch 2025-09-14 16:51:55.129000: 1000 trades
# 2025-09-14 17:04:18,181 - INFO -   Batch 2025-09-14 16:54:55.799000: 1000 trades
# 2025-09-14 17:04:19,070 - INFO -   Batch 2025-09-14 16:58:22.552000: 1000 trades
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 instance = HistoricalDataCollector(days = 0.01, type = "spot", symbols = ["ETH-USDT"])
# ----> 2 instance.collect_historical_trades()
#
# ...
