# %%
from hist_data import HistoricalDataCollector
instance = HistoricalDataCollector(days = 1, type = "future")
perp = ["ETH-USDT-PERP"]
# Out:
# 2025-09-14 16:51:01,927 - INFO - Historical Data Collector initialized for 1 days

# %% [markdown]
# Saves it into csv files in /historical_data

# %%
instance.collect_historical_funding_rates(perp)
# Out:
# 2025-09-14 16:51:01,952 - INFO - Collecting historical funding rates for 1 symbols...
# 2025-09-14 16:51:01,954 - INFO - Collecting funding rates for ETH-USDT-PERP...

# %%
instance.collect_historical_open_interest(perp, timeframe = '1h')

# %%
instance.collect_historical_ohlcv(perp, timeframe = "5m")

# %%
# too much data otherwise
instance = HistoricalDataCollector(days = 0.01)
instance.collect_historical_trades(perp)

# %%
instance = HistoricalDataCollector(days = 1, type = "spot")
spot = ["ETH-USDT"]
# Out:
# 2025-09-14 16:49:53,606 - INFO - Historical Data Collector initialized for 1 days

# %%
instance.collect_historical_ohlcv(spot)
# Out:
# 2025-09-14 16:49:55,193 - INFO - Collecting historical OHLCV data (15m) for 1 symbols...
# 2025-09-14 16:49:55,195 - INFO - Total periods needed: 96
# 2025-09-14 16:49:55,197 - INFO - Number of batches: 1
# 2025-09-14 16:49:55,200 - INFO - Collecting ETH-USDT...
# 2025-09-14 16:50:02,434 - INFO -   Batch 1/1: 96 records
# 2025-09-14 16:50:02,551 - INFO -   Saved ETH-USDT: 96 records to ETH-USDT_15m_1d.csv
# 2025-09-14 16:50:02,553 - INFO - Collecting historical trades for 1 symbols (last 1 days)...
# 2025-09-14 16:50:02,555 - INFO - Collecting trades for ETH-USDT...
# 2025-09-14 16:50:02,847 - INFO -   Batch 2025-09-13 16:50:02.557635: 1000 trades
# 2025-09-14 16:50:03,683 - INFO -   Batch 2025-09-13 16:51:00.068000: 1000 trades
# 2025-09-14 16:50:04,495 - INFO -   Batch 2025-09-13 16:52:19.128000: 1000 trades
# 2025-09-14 16:50:05,309 - INFO -   Batch 2025-09-13 16:54:13.066000: 1000 trades
# 2025-09-14 16:50:06,138 - INFO -   Batch 2025-09-13 16:56:14.709000: 1000 trades
# ...

# %%
instance = HistoricalDataCollector(days = 0.01)
instance.collect_historical_trades(spot)

# %%
instance.collect_historical_funding_rates(perp)
