# %%
from hist_data import HistoricalDataCollector
instance = HistoricalDataCollector(years = 1)
perp = ["ETH-USDT-PERP"]
# Out:
# 2025-09-14 15:14:32,873 - INFO - Historical Data Collector initialized for 1 years

# %% [markdown]
# Saves it into csv files in /historical_data

# %%
instance.collect_historical_funding_rates(perp)
# Out:
# 2025-09-14 15:14:32,891 - INFO - Collecting historical funding rates for 1 symbols...
# 2025-09-14 15:14:32,892 - INFO - Collecting funding rates for ETH-USDT-PERP...
# 2025-09-14 15:14:49,857 - INFO -   Saved ETH-USDT-PERP: 1,000 funding rate records to ETH-USDT-PERP_funding_rates_1y.csv

# %%
instance.collect_historical_open_interest(perp)
# Out:
# 2025-09-14 15:14:50,380 - INFO - Collecting historical open interest for 1 symbols...
# 2025-09-14 15:14:50,382 - INFO - Collecting open interest for ETH-USDT-PERP...
# 2025-09-14 15:14:50,382 - INFO -   Fetching batch 1 from 2024-09-14 15:14:50
# 2025-09-14 15:14:50,651 - WARNING -   API error for batch 1 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:14:50,656 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:14:51,043 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:14:51,045 - INFO -   Fetching batch 2 from 2024-09-14 15:14:50
# 2025-09-14 15:14:51,047 - INFO -   Rate limiting: sleeping 1.1s
# 2025-09-14 15:14:52,390 - WARNING -   API error for batch 2 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:14:52,392 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:14:52,719 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:14:52,721 - INFO -   Fetching batch 3 from 2024-09-14 15:14:50
# 2025-09-14 15:14:52,722 - INFO -   Rate limiting: sleeping 1.2s
# 2025-09-14 15:14:54,162 - WARNING -   API error for batch 3 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:14:54,164 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:14:54,514 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:14:54,517 - INFO -   Fetching batch 4 from 2024-09-14 15:14:50
# 2025-09-14 15:14:54,518 - INFO -   Rate limiting: sleeping 1.3s
# 2025-09-14 15:14:56,145 - WARNING -   API error for batch 4 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:14:56,150 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:14:56,954 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:14:56,955 - INFO -   Fetching batch 5 from 2024-09-14 15:14:50
# 2025-09-14 15:14:56,957 - INFO -   Rate limiting: sleeping 1.4s
# 2025-09-14 15:14:58,600 - WARNING -   API error for batch 5 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:14:58,601 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:14:58,878 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:14:58,879 - INFO -   Fetching batch 6 from 2024-09-14 15:14:50
# 2025-09-14 15:14:58,880 - INFO -   Rate limiting: sleeping 1.5s
# 2025-09-14 15:15:00,967 - WARNING -   API error for batch 6 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:00,969 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:01,696 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:01,697 - INFO -   Fetching batch 7 from 2024-09-14 15:14:50
# 2025-09-14 15:15:01,699 - INFO -   Rate limiting: sleeping 1.6s
# 2025-09-14 15:15:04,032 - WARNING -   API error for batch 7 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:04,034 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:04,877 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:04,879 - INFO -   Fetching batch 8 from 2024-09-14 15:14:50
# 2025-09-14 15:15:04,883 - INFO -   Rate limiting: sleeping 1.7s
# 2025-09-14 15:15:06,928 - WARNING -   API error for batch 8 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:06,929 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:07,389 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:07,391 - INFO -   Fetching batch 9 from 2024-09-14 15:14:50
# 2025-09-14 15:15:07,392 - INFO -   Rate limiting: sleeping 1.8s
# 2025-09-14 15:15:09,431 - WARNING -   API error for batch 9 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:09,432 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:09,708 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:09,711 - INFO -   Fetching batch 10 from 2024-09-14 15:14:50
# 2025-09-14 15:15:09,712 - INFO -   Rate limiting: sleeping 1.9s
# 2025-09-14 15:15:12,066 - WARNING -   API error for batch 10 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:12,069 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:12,534 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:12,536 - INFO -   Fetching batch 11 from 2024-09-14 15:14:50
# 2025-09-14 15:15:12,538 - INFO -   Rate limiting: sleeping 2.0s
# 2025-09-14 15:15:14,799 - WARNING -   API error for batch 11 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:14,801 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:15,291 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:15,293 - INFO -   Fetching batch 12 from 2024-09-14 15:14:50
# 2025-09-14 15:15:15,295 - INFO -   Rate limiting: sleeping 2.1s
# 2025-09-14 15:15:17,758 - WARNING -   API error for batch 12 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:17,760 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:19,058 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:19,060 - INFO -   Fetching batch 13 from 2024-09-14 15:14:50
# 2025-09-14 15:15:19,062 - INFO -   Rate limiting: sleeping 2.2s
# 2025-09-14 15:15:21,678 - WARNING -   API error for batch 13 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:21,680 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:22,111 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:22,113 - INFO -   Fetching batch 14 from 2024-09-14 15:14:50
# 2025-09-14 15:15:22,115 - INFO -   Rate limiting: sleeping 2.3s
# 2025-09-14 15:15:25,221 - WARNING -   API error for batch 14 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:25,223 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:25,751 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:25,751 - INFO -   Fetching batch 15 from 2024-09-14 15:14:50
# 2025-09-14 15:15:25,753 - INFO -   Rate limiting: sleeping 2.4s
# 2025-09-14 15:15:28,408 - WARNING -   API error for batch 15 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:28,410 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:28,676 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:28,678 - INFO -   Fetching batch 16 from 2024-09-14 15:14:50
# 2025-09-14 15:15:28,680 - INFO -   Rate limiting: sleeping 2.5s
# 2025-09-14 15:15:31,429 - WARNING -   API error for batch 16 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:31,431 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:31,699 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:31,702 - INFO -   Fetching batch 17 from 2024-09-14 15:14:50
# 2025-09-14 15:15:31,702 - INFO -   Rate limiting: sleeping 2.6s
# 2025-09-14 15:15:34,596 - WARNING -   API error for batch 17 (attempt 1): binance {"msg":"parameter 'startTime' is invalid.","code":-1130}
# 2025-09-14 15:15:34,598 - WARNING -   Invalid startTime, trying without since parameter...
# 2025-09-14 15:15:34,896 - INFO -   Fetched 500 records without since parameter
# 2025-09-14 15:15:34,898 - INFO -   Fetching batch 18 from 2024-09-14 15:14:50
# 2025-09-14 15:15:34,898 - INFO -   Rate limiting: sleeping 2.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 instance.collect_historical_open_interest(perp)
#
# File c:\Users\Leo\hku_stuff\data_work_59q897\hist_data.py:192, in HistoricalDataCollector.collect_historical_open_interest(self, symbols)
#     190     sleep_time = min(1.0 + (batch_count * 0.1), 5.0)  # Max 5 seconds
#     191     logger.info(f"  Rate limiting: sleeping {sleep_time:.1f}s")
# --> 192     time.sleep(sleep_time)
#     194 open_interest = self.exchange.fetch_open_interest_history(
#     195     ccxt_symbol,
#     196     since=int(current_start_time.timestamp() * 1000),
#     197     limit=1000  # Reduced limit to avoid API errors
#     198 )
#     200 if not open_interest:
#
# KeyboardInterrupt:
