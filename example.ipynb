# %%
from hist_data import HistoricalDataCollector
instance = HistoricalDataCollector(days = 1, type = "future", symbols = ["ETH-USDT-PERP"])
# Out:
# 2025-09-14 17:02:38,167 - INFO - Historical Data Collector initialized for 1 days

# %% [markdown]
# Where timeframe is available it can be "5m","15m","30m","1h","2h","4h","6h","12h", or "1d"

# %% [markdown]
# Saves it into csv files in /historical_data

# %%
instance.collect_historical_funding_rates()
# Out:
# 2025-09-14 17:02:38,272 - INFO - Collecting historical funding rates for 1 symbols...
# 2025-09-14 17:02:38,274 - INFO - Collecting funding rates for ETH-USDT-PERP...
# 2025-09-14 17:02:45,185 - INFO -   Saved ETH-USDT-PERP: 3 funding rate records to future_ETH-USDT-PERP_funding_rates_1d.csv

# %%
instance.collect_historical_open_interest( timeframe = '5m')
# Out:
# 2025-09-14 17:02:45,745 - INFO - Collecting historical open interest for 1 symbols...
# 2025-09-14 17:02:45,750 - INFO - Collecting open interest for ETH-USDT-PERP...
# 2025-09-13 17:02:45.752911
# 2025-09-14 17:02:46,013 - INFO -   Fetched 288 records (total: 288)
# 2025-09-14 17:02:46,030 - INFO -   Saved ETH-USDT-PERP: 288 open interest records to future_ETH-USDT-PERP_open_interest_1d_5m.csv

# %%
instance.collect_historical_ohlcv( timeframe = "5m")
# Out:
# 2025-09-14 17:02:48,060 - INFO - Collecting historical OHLCV data (5m) for 1 symbols...
# 2025-09-14 17:02:48,062 - INFO - Total periods needed: 96
# 2025-09-14 17:02:48,063 - INFO - Number of batches: 1
# 2025-09-14 17:02:48,063 - INFO - Collecting ETH-USDT-PERP...
# 2025-09-14 17:02:48,338 - INFO -   Batch 1/1: 288 records
# 2025-09-14 17:02:48,469 - INFO -   Saved ETH-USDT-PERP: 288 records to future_ETH-USDT-PERP_5m_1d.csv

# %%
# too much data otherwise
instance = HistoricalDataCollector(days = 0.01, type = "future", symbols = ["ETH-USDT-PERP"])
instance.collect_historical_trades()
# Out:
# 2025-09-14 17:03:02,617 - INFO - Historical Data Collector initialized for 0.01 days
# 2025-09-14 17:03:02,683 - INFO - Collecting historical trades for 1 symbols (last 0.01 days)...
# 2025-09-14 17:03:02,685 - INFO - Collecting trades for ETH-USDT-PERP...
# 2025-09-14 17:03:11,863 - INFO -   Batch 2025-09-14 16:48:38.688327: 1000 trades
# 2025-09-14 17:03:13,142 - INFO -   Batch 2025-09-14 16:50:04.909000: 1000 trades
# 2025-09-14 17:03:13,999 - INFO -   Batch 2025-09-14 16:51:12.938000: 1000 trades
# 2025-09-14 17:03:14,977 - INFO -   Batch 2025-09-14 16:52:37.522000: 1000 trades
# 2025-09-14 17:03:15,996 - INFO -   Batch 2025-09-14 16:54:13.497000: 1000 trades
# 2025-09-14 17:03:17,109 - INFO -   Batch 2025-09-14 16:55:46.236000: 1000 trades
# 2025-09-14 17:03:18,086 - INFO -   Batch 2025-09-14 16:57:27.606000: 1000 trades
# 2025-09-14 17:03:19,173 - INFO -   Batch 2025-09-14 16:59:11.117000: 1000 trades
# 2025-09-14 17:03:20,137 - INFO -   Batch 2025-09-14 17:00:23.356000: 1000 trades
# 2025-09-14 17:03:21,097 - INFO -   Batch 2025-09-14 17:01:23.645000: 1000 trades
# 2025-09-14 17:03:22,261 - INFO -   Batch 2025-09-14 17:02:21.031000: 1000 trades
# 2025-09-14 17:03:23,219 - INFO -   Saved ETH-USDT-PERP: 10,933 trade records to future_ETH-USDT-PERP_trades_0.01d.csv

# %%
instance = HistoricalDataCollector(days = 1, type = "spot", symbols = ["ETH-USDT"])
# Out:
# 2025-09-14 17:04:24,535 - INFO - Historical Data Collector initialized for 1 days

# %%
instance.collect_historical_ohlcv(timeframe = "5m")
# Out:
# 2025-09-14 17:03:50,178 - INFO - Collecting historical OHLCV data (5m) for 1 symbols...
# 2025-09-14 17:03:50,180 - INFO - Total periods needed: 96
# 2025-09-14 17:03:50,182 - INFO - Number of batches: 1
# 2025-09-14 17:03:50,183 - INFO - Collecting ETH-USDT...
# 2025-09-14 17:03:50,455 - INFO -   Batch 1/1: 288 records
# 2025-09-14 17:03:50,576 - INFO -   Saved ETH-USDT: 288 records to spot_ETH-USDT_5m_1d.csv

# %%
instance = HistoricalDataCollector(days = 0.01, type = "spot", symbols = ["ETH-USDT"])
instance.collect_historical_trades()
# Out:
# 2025-09-14 17:04:07,951 - INFO - Historical Data Collector initialized for 0.01 days
# 2025-09-14 17:04:08,016 - INFO - Collecting historical trades for 1 symbols (last 0.01 days)...
# 2025-09-14 17:04:08,020 - INFO - Collecting trades for ETH-USDT...
# 2025-09-14 17:04:16,561 - INFO -   Batch 2025-09-14 16:49:44.023982: 1000 trades
# 2025-09-14 17:04:17,371 - INFO -   Batch 2025-09-14 16:51:55.129000: 1000 trades
# 2025-09-14 17:04:18,181 - INFO -   Batch 2025-09-14 16:54:55.799000: 1000 trades
# 2025-09-14 17:04:19,070 - INFO -   Batch 2025-09-14 16:58:22.552000: 1000 trades
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 instance = HistoricalDataCollector(days = 0.01, type = "spot", symbols = ["ETH-USDT"])
# ----> 2 instance.collect_historical_trades()
#
# File c:\Users\Leo\hku_stuff\data_work_59q897\hist_data.py:285, in HistoricalDataCollector.collect_historical_trades(self)
#     282     else:
#     283         break
# --> 285     time.sleep(0.5)  # Rate limiting
#     287 except Exception as e:
#     288     logger.error(f"  Error in trades batch {start_time}: {e}")
#
# KeyboardInterrupt:
