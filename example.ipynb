# %%
from src.hist_data import HistoricalDataCollector
instance = HistoricalDataCollector()

# %% [markdown]
# Give the coins in ETH-USDT Format, the format is converted to native ccxt internally

# %%
from datetime import datetime, timedelta
end_date = datetime(2025, 9, 23, 12, 0, 0)
start_date = end_date - timedelta(days=15, hours=12, minutes=15, seconds=15)
a = instance.load_data_period(symbol = "ETH-USDT", timeframe = "15m", data_type = 'ohlcv_spot', start_date = start_date, end_date = end_date, export = True)
# Out:
# 2025-09-23 16:17:59,322 - INFO - Collecting spot OHLCV for ETH-USDT...
# 2025-09-23 16:18:00,405 - INFO -   Data collection batch 1/2: 1000 records
# 2025-09-23 16:18:01,731 - INFO -   Data collection batch 2/2: 1000 records
# 2025-09-23 16:18:01,911 - INFO -   Saved spot OHLCV for ETH-USDT: 2,000 records to spot_ETH-USDT_ohlcv_15m_20250907_234445_20250923_161759.parquet
# 2025-09-23 16:18:01,915 - INFO - Collecting perpetual index price OHLCV for ETH-USDT...
# 2025-09-23 16:18:02,409 - INFO -   Data collection batch 1/2: 1000 records
# 2025-09-23 16:18:02,752 - INFO -   Data collection batch 2/2: 1000 records
# 2025-09-23 16:18:02,854 - INFO -   Saved perpetual index OHLCV for ETH-USDT: 2,000 records to perpetual_ETH-USDT_index_15m_20250907_234445_20250923_161801.parquet
# 2025-09-23 16:18:02,863 - INFO - Collecting perpetual mark price OHLCV for ETH-USDT...
# 2025-09-23 16:18:03,539 - INFO -   Data collection batch 1/2: 1000 records
# 2025-09-23 16:18:03,975 - INFO -   Data collection batch 2/2: 1000 records
# 2025-09-23 16:18:04,092 - INFO -   Saved perpetual mark OHLCV for ETH-USDT: 2,000 records to perpetual_ETH-USDT_mark_15m_20250907_234445_20250923_161802.parquet
# 2025-09-23 16:18:04,097 - INFO - Collecting funding rates for ETH-USDT...
# c:\Users\Leo\hku_stuff\data_work_59q897\src\hist_data.py:371: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df['funding_time'] = pd.to_datetime(df['funding_time'], unit='ms', errors='coerce')
# 2025-09-23 16:18:04,296 - INFO -   Saved funding rates for ETH-USDT: 47 records to perpetual_ETH-USDT_funding_rates_20250907_234445_20250923_161804.parquet
# 2025-09-23 16:18:04,299 - INFO - Collecting open interest for ETH-USDT...
# 2025-09-23 16:18:04,599 - INFO -   Data collection batch 1/2: 1000 records
# 2025-09-23 16:18:05,032 - INFO -   Data collection batch 2/2: 1000 records
# 2025-09-23 16:18:05,462 - INFO -   Saved open interest for ETH-USDT: 2,000 records to perpetual_ETH-USDT_open_interest_15m_20250907_234445_20250923_161804.parquet

# %%
a = await instance.collect_live_spot_ohlcv("ETH-USDT")
# Out:
# 2025-09-28 15:20:18,294 - ERROR - Failed to collect live spot OHLCV data for ETH/USDT: list indices must be integers or slices, not str

# %%
a

# %%
for i in [ "ohlcv_spot", "index_ohlcv_futures", "mark_ohlcv_futures", "funding_rates", "open_interest", "trades_futures"]:
    instance.load_data_period

# %% [markdown]
# Where timeframe is available it can be "5m","15m","30m","1h","2h","4h","6h","12h", or "1d"

# %% [markdown]
# Saves it into csv files in /historical_data

# %%
instance.collect_funding_rates("ETH-USDT", days = 1)
# Out:
# 2025-09-22 14:50:30,828 - INFO - Collecting funding rates for ETH-USDT...
# 2025-09-22 14:50:31,087 - INFO -   Saved funding rates for ETH-USDT: 3 records to perpetual_ETH-USDT_funding_rates_1d.parquet
# [{'info': {'symbol': 'ETHUSDT', 'fundingTime': '1758470400000', 'fundingRate': '0.00003039', 'markPrice': '4480.92020930'}, 'symbol': 'ETH/USDT:USDT', 'fundingRate': 3.039e-05, 'timestamp': 1758470400000, 'datetime': '2025-09-21T16:00:00.000Z'}, {'info': {'symbol': 'ETHUSDT', 'fundingTime': '1758499200005', 'fundingRate': '-0.00002051', 'markPrice': '4443.33000000'}, 'symbol': 'ETH/USDT:USDT', 'fundingRate': -2.051e-05, 'timestamp': 1758499200005, 'datetime': '2025-09-22T00:00:00.005Z'}, {'info': {'symbol': 'ETHUSDT', 'fundingTime': '1758528000003', 'fundingRate': '-0.00000518', 'markPrice': '4191.68000000'}, 'symbol': 'ETH/USDT:USDT', 'fundingRate': -5.18e-06, 'timestamp': 1758528000003, 'datetime': '2025-09-22T08:00:00.003Z'}]

# %%
a =instance.collect_perpetual_index_ohlcv("ETH-USDT", days = 1)

# %%
instance.collect_open_interest("ETH-USDT", days = 1)
# Out:
#              timestamp  open_interest  open_interest_value contract_type  \
# 0  2025-09-21 14:00:00    2026199.655         9.065338e+09     perpetual
# 1  2025-09-21 14:15:00    2026364.150         9.072246e+09     perpetual
# 2  2025-09-21 14:30:00    2025827.182         9.062538e+09     perpetual
# 3  2025-09-21 14:45:00    2025828.533         9.070865e+09     perpetual
# 4  2025-09-21 15:00:00    2027552.000         9.065284e+09     perpetual
# ..                 ...            ...                  ...           ...
# 91 2025-09-22 12:45:00    1973360.096         8.245490e+09     perpetual
# 92 2025-09-22 13:00:00    1970886.834         8.259069e+09     perpetual
# 93 2025-09-22 13:15:00    1972239.855         8.290419e+09     perpetual
# 94 2025-09-22 13:30:00    1974026.494         8.294480e+09     perpetual
# 95 2025-09-22 13:45:00    1968255.020         8.227702e+09     perpetual
#
#       symbol market_type
# 0   ETH-USDT   perpetual
# 1   ETH-USDT   perpetual
# 2   ETH-USDT   perpetual
# 3   ETH-USDT   perpetual
# 4   ETH-USDT   perpetual
# ..       ...         ...
# 91  ETH-USDT   perpetual
# 92  ETH-USDT   perpetual
# 93  ETH-USDT   perpetual
# 94  ETH-USDT   perpetual
# 95  ETH-USDT   perpetual
#
# [96 rows x 6 columns]
