# %%
from hist_data import HistoricalDataCollector
instance = HistoricalDataCollector(days = 1)
perp = ["ETH-USDT-PERP"]
# Out:
# 2025-09-14 16:33:29,599 - INFO - Historical Data Collector initialized for 0.1 days

# %% [markdown]
# Saves it into csv files in /historical_data

# %%
instance.collect_historical_funding_rates(perp)
# Out:
# 2025-09-14 15:36:05,832 - INFO - Collecting historical funding rates for 1 symbols...
# 2025-09-14 15:36:05,833 - INFO - Collecting funding rates for ETH-USDT-PERP...
# 2025-09-14 15:36:16,254 - INFO -   Saved ETH-USDT-PERP: 1,000 funding rate records to ETH-USDT-PERP_funding_rates_1y.csv

# %%
instance.collect_historical_open_interest(perp, timeframe = '1h')
# Out:
# 2025-09-14 16:24:27,832 - INFO - Collecting historical open interest for 1 symbols...
# 2025-09-14 16:24:27,834 - INFO - Collecting open interest for ETH-USDT-PERP...
# 2025-08-14 16:24:27.836618
# 2025-09-14 16:24:28,074 - ERROR - Failed to collect open interest for ETH-USDT-PERP: binance {"msg":"parameter 'startTime' is invalid.","code":-1130}

# %%
instance.collect_historical_ohlcv(perp, timeframe = "5m")
# Out:
# 2025-09-14 16:30:30,497 - INFO - Collecting historical OHLCV data (5m) for 1 symbols...
# 2025-09-14 16:30:30,499 - INFO - Total periods needed: 96
# 2025-09-14 16:30:30,501 - INFO - Number of batches: 1
# 2025-09-14 16:30:30,501 - INFO - Collecting ETH-USDT-PERP...
# 2025-09-14 16:30:37,711 - INFO -   Batch 1/1: 288 records
# 2025-09-14 16:30:37,836 - INFO -   Saved ETH-USDT-PERP: 288 records to ETH-USDT-PERP_5m_1d.csv

# %%
# too much data otherwise
instance = HistoricalDataCollector(days = 0.01)
instance.collect_historical_trades(perp)
# Out:
# 2025-09-14 16:33:33,303 - INFO - Collecting historical trades for 1 symbols (last 0.1 days)...
# 2025-09-14 16:33:33,305 - INFO - Collecting trades for ETH-USDT-PERP...
# 2025-09-14 16:33:40,033 - INFO -   Batch 2025-09-14 14:09:33.306307: 1000 trades
# 2025-09-14 16:33:41,031 - INFO -   Batch 2025-09-14 14:10:35.313000: 1000 trades
# 2025-09-14 16:33:42,044 - INFO -   Batch 2025-09-14 14:12:24.507000: 1000 trades
# 2025-09-14 16:33:43,034 - INFO -   Batch 2025-09-14 14:14:04.027000: 1000 trades
# 2025-09-14 16:33:44,043 - INFO -   Batch 2025-09-14 14:15:29.043000: 1000 trades
# 2025-09-14 16:33:45,076 - INFO -   Batch 2025-09-14 14:17:08.187000: 1000 trades
# 2025-09-14 16:33:46,047 - INFO -   Batch 2025-09-14 14:18:41.922000: 1000 trades
# 2025-09-14 16:33:47,034 - INFO -   Batch 2025-09-14 14:19:45.748000: 1000 trades
# 2025-09-14 16:33:48,073 - INFO -   Batch 2025-09-14 14:21:00.715000: 1000 trades
# 2025-09-14 16:33:49,052 - INFO -   Batch 2025-09-14 14:22:12.415000: 1000 trades
# 2025-09-14 16:33:50,045 - INFO -   Batch 2025-09-14 14:22:55.501000: 1000 trades
# 2025-09-14 16:33:51,039 - INFO -   Batch 2025-09-14 14:23:51.256000: 1000 trades
# 2025-09-14 16:33:52,042 - INFO -   Batch 2025-09-14 14:24:34.032000: 1000 trades
# 2025-09-14 16:33:53,039 - INFO -   Batch 2025-09-14 14:25:02.045000: 1000 trades
# 2025-09-14 16:33:54,044 - INFO -   Batch 2025-09-14 14:25:57.306000: 1000 trades
# 2025-09-14 16:33:55,040 - INFO -   Batch 2025-09-14 14:27:35.903000: 1000 trades
# 2025-09-14 16:33:56,051 - INFO -   Batch 2025-09-14 14:28:25.561000: 1000 trades
# 2025-09-14 16:33:57,051 - INFO -   Batch 2025-09-14 14:28:56.880000: 1000 trades
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 instance.collect_historical_trades(perp)
#
# File c:\Users\Leo\hku_stuff\data_work_59q897\hist_data.py:264, in HistoricalDataCollector.collect_historical_trades(self, symbols)
#     261     else:
#     262         break
# --> 264     time.sleep(0.5)  # Rate limiting
#     266 except Exception as e:
#     267     logger.error(f"  Error in trades batch {start_time}: {e}")
#
# KeyboardInterrupt:
