# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt

files = glob.glob("../hku-data/test_data/*.csv")
data_list = []

for f in files:
    df = pd.read_csv(f)
    print(f"{f}: {len(df)} rows")

    df['date'] = pd.to_datetime(df['timestamp'], errors='coerce')
    if df['date'].isna().sum() > 0:
        print(f"⚠️ Warning: {df['date'].isna().sum()} invalid dates in {f}")


    df['symbol'] = f.split('/')[-1].replace('.csv','')
    data_list.append(df)

data = pd.concat(data_list)
print(f"\nВсего строк после объединения: {len(data)}")

before_drop = len(data)
data = data.drop_duplicates(subset=['date', 'symbol'])
print(f"Удалено дубликатов: {before_drop - len(data)}")
print(f"Итого строк после очистки: {len(data)}")

# Сортируем
data.sort_values(by=['date', 'symbol'], inplace=True)

n = 20  # period in days
data['return'] = data.groupby('symbol')['close'].pct_change(n)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 9
# ../hku-data/test_data\1000BONK-USDT-PERP_15m_1460d.csv: 63344 rows
# ../hku-data/test_data\1000FLOKI-USDT-PERP_15m_1460d.csv: 82530 rows
# ../hku-data/test_data\1000PEPE-USDT-PERP_15m_1460d.csv: 82626 rows
# ../hku-data/test_data\1000SHIB-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\AAVE-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\ACH-USDT-PERP_15m_1460d.csv: 89546 rows
# ../hku-data/test_data\ADA-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\ALGO-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\APE-USDT-PERP_15m_1460d.csv: 122372 rows
# ../hku-data/test_data\APT-USDT-PERP_15m_1460d.csv: 101688 rows
# ../hku-data/test_data\AR-USDT-PERP_15m_1460d.csv: 138734 rows
# ../hku-data/test_data\ARB-USDT-PERP_15m_1460d.csv: 86760 rows
# ../hku-data/test_data\ATOM-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\AVA-USDT-PERP_15m_1460d.csv: 26200 rows
# ../hku-data/test_data\AVAX-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\AXL-USDT-PERP_15m_1460d.csv: 53738 rows
# ../hku-data/test_data\AXS-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\BAND-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\BCH-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\BNB-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\BTC-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\CAKE-USDT-PERP_15m_1460d.csv: 65269 rows
# ../hku-data/test_data\CELR-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\CFX-USDT-PERP_15m_1460d.csv: 89738 rows
# ../hku-data/test_data\COMP-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\CRV-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\CVC-USDT-PERP_15m_1460d.csv: 11434 rows
# ../hku-data/test_data\CVX-USDT-PERP_15m_1460d.csv: 4894 rows
# ../hku-data/test_data\DEXE-USDT-PERP_15m_1460d.csv: 25150 rows
# ../hku-data/test_data\DOGE-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\DOT-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\DYDX-USDT-PERP_15m_1460d.csv: 140462 rows
# ../hku-data/test_data\EIGEN-USDT-PERP_15m_1460d.csv: 33232 rows
# ../hku-data/test_data\ENA-USDT-PERP_15m_1460d.csv: 50678 rows
# ../hku-data/test_data\ENS-USDT-PERP_15m_1460d.csv: 132690 rows
# ../hku-data/test_data\ETC-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\ETH-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\ETHFI-USDT-PERP_15m_1460d.csv: 52106 rows
# ../hku-data/test_data\FET-USDT-PERP_15m_1460d.csv: 93050 rows
# ../hku-data/test_data\FIL-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\FLUX-USDT-PERP_15m_1460d.csv: 35916 rows
# ../hku-data/test_data\FORTH-USDT-PERP_15m_1460d.csv: 15082 rows
# ../hku-data/test_data\GALA-USDT-PERP_15m_1460d.csv: 139694 rows
# ../hku-data/test_data\GLM-USDT-PERP_15m_1460d.csv: 54528 rows
# ../hku-data/test_data\GRT-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\HBAR-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\HIGH-USDT-PERP_15m_1460d.csv: 91034 rows
# ../hku-data/test_data\ICP-USDT-PERP_15m_1460d.csv: 103798 rows
# ../hku-data/test_data\ICX-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\INJ-USDT-PERP_15m_1460d.csv: 107733 rows
# ../hku-data/test_data\IOTA-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\JOE-USDT-PERP_15m_1460d.csv: 86196 rows
# ../hku-data/test_data\JTO-USDT-PERP_15m_1460d.csv: 61824 rows
# ../hku-data/test_data\JUP-USDT-PERP_15m_1460d.csv: 56606 rows
# ../hku-data/test_data\KAIA-USDT-PERP_15m_1460d.csv: 27060 rows
# ../hku-data/test_data\LDO-USDT-PERP_15m_1460d.csv: 104240 rows
# ../hku-data/test_data\LINK-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\LPT-USDT-PERP_15m_1460d.csv: 134514 rows
# ../hku-data/test_data\LTC-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\MANA-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\MKR-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\MLN-USDT-PERP_15m_1460d.csv: 15849 rows
# ../hku-data/test_data\MOVE-USDT-PERP_15m_1460d.csv: 26580 rows
# ../hku-data/test_data\MTL-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\NEAR-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\NEO-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\NKN-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\NMR-USDT-PERP_15m_1460d.csv: 78036 rows
# ../hku-data/test_data\NOT-USDT-PERP_15m_1460d.csv: 46448 rows
# ../hku-data/test_data\NTRN-USDT-PERP_15m_1460d.csv: 64120 rows
# ../hku-data/test_data\OGN-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\OM-USDT-PERP_15m_1460d.csv: 55376 rows
# ../hku-data/test_data\ONDO-USDT-PERP_15m_1460d.csv: 57684 rows
# ../hku-data/test_data\OP-USDT-PERP_15m_1460d.csv: 115080 rows
# ../hku-data/test_data\ORDI-USDT-PERP_15m_1460d.csv: 64790 rows
# ../hku-data/test_data\OXT-USDT-PERP_15m_1460d.csv: 73236 rows
# ../hku-data/test_data\PAXG-USDT-PERP_15m_1460d.csv: 16226 rows
# ../hku-data/test_data\PENDLE-USDT-PERP_15m_1460d.csv: 74618 rows
# ../hku-data/test_data\POL-USDT-PERP_15m_1460d.csv: 34935 rows
# ../hku-data/test_data\POWR-USDT-PERP_15m_1460d.csv: 65886 rows
# ../hku-data/test_data\PYTH-USDT-PERP_15m_1460d.csv: 63342 rows
# ../hku-data/test_data\QNT-USDT-PERP_15m_1460d.csv: 101590 rows
# ../hku-data/test_data\RENDER-USDT-PERP_15m_1460d.csv: 39648 rows
# ../hku-data/test_data\RIF-USDT-PERP_15m_1460d.csv: 66418 rows
# ../hku-data/test_data\RLC-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\ROSE-USDT-PERP_15m_1460d.csv: 129714 rows
# ../hku-data/test_data\RSR-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\RUNE-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\SAND-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\SANTOS-USDT-PERP_15m_1460d.csv: 30612 rows
# ../hku-data/test_data\SCRT-USDT-PERP_15m_1460d.csv: 28318 rows
# ../hku-data/test_data\SEI-USDT-PERP_15m_1460d.csv: 72698 rows
# ../hku-data/test_data\SOL-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\SPELL-USDT-PERP_15m_1460d.csv: 105776 rows
# ../hku-data/test_data\STG-USDT-PERP_15m_1460d.csv: 106928 rows
# ../hku-data/test_data\STORJ-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\STRK-USDT-PERP_15m_1460d.csv: 54692 rows
# ../hku-data/test_data\STX-USDT-PERP_15m_1460d.csv: 89642 rows
# ../hku-data/test_data\SUI-USDT-PERP_15m_1460d.csv: 82820 rows
# ../hku-data/test_data\SUN-USDT-PERP_15m_1460d.csv: 37044 rows
# ../hku-data/test_data\SUPER-USDT-PERP_15m_1460d.csv: 62964 rows
# ../hku-data/test_data\TAO-USDT-PERP_15m_1460d.csv: 49806 rows
# ../hku-data/test_data\THETA-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\TIA-USDT-PERP_15m_1460d.csv: 65440 rows
# ../hku-data/test_data\TON-USDT-PERP_15m_1460d.csv: 53750 rows
# ../hku-data/test_data\TRX-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\TURBO-USDT-PERP_15m_1460d.csv: 45098 rows
# ../hku-data/test_data\TWT-USDT-PERP_15m_1460d.csv: 65166 rows
# ../hku-data/test_data\UNI-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\VET-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\WLD-USDT-PERP_15m_1460d.csv: 74964 rows
# ../hku-data/test_data\XLM-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\XRP-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\XTZ-USDT-PERP_15m_1460d.csv: 140984 rows
# ../hku-data/test_data\ZK-USDT-PERP_15m_1460d.csv: 43388 rows
# ../hku-data/test_data\ZRO-USDT-PERP_15m_1460d.csv: 43086 rows
#
# Всего строк после объединения: 11210514
# Удалено дубликатов: 0
# Итого строк после очистки: 11210514

# %%
# === 4. Cross-sectional rank + Enhanced Momentum ===
def cross_section_rank(group):
    group = group.copy()
    group['cs_rank'] = group['return'].rank(pct=True)

    if group['volume'].std() > 0:
        vol_scaled = (group['volume'] - group['volume'].mean()) / group['volume'].std()
    else:
        vol_scaled = 0
    group['enhanced_mom'] = (group['cs_rank'] - 0.5) * (1 + 0.1 * vol_scaled)
    return group

data = (
    data.groupby('date', group_keys=False)[['symbol','return','volume']]
        .apply(cross_section_rank)
)


top_threshold = 0.4
bottom_threshold = -0.4

data['signal'] = 0
data.loc[data['enhanced_mom'] > top_threshold, 'signal'] = 1
data.loc[data['enhanced_mom'] < bottom_threshold, 'signal'] = -1

data.to_csv("cross_section_enhanced_momentum_signals.csv", index=False)
print(data.head(20))

plt.figure(figsize=(12,6))
data.groupby('date')['signal'].mean().plot(title="Mean signal among all currencies")
plt.xlabel("Date")
plt.ylabel("Mean signal")
plt.show()
